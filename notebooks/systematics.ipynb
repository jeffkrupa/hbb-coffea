# %%
import pandas as pd
import numpy as np

from plotter import *
# Out:
# /opt/conda/lib/python3.8/site-packages/coffea/util.py:154: FutureWarning: In coffea version v0.8.0 (target date: 31 Dec 2022), this will be an error.
# (Set coffea.deprecations_as_errors = True to get a stack trace now.)
# ImportError: coffea.hist is deprecated
#   warnings.warn(message, FutureWarning)

# %%
df16apv = pd.read_csv('2016APV/systematics.csv',index_col=0).reset_index(drop=True)
df16 = pd.read_csv('2016/systematics.csv',index_col=0).reset_index(drop=True)
df17 = pd.read_csv('2017/systematics.csv',index_col=0).reset_index(drop=True)
df18 = pd.read_csv('2018/systematics.csv',index_col=0).reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [3], in <cell line: 3>()
#       1 df16apv = pd.read_csv('2016APV/systematics.csv',index_col=0).reset_index(drop=True)
#       2 df16 = pd.read_csv('2016/systematics.csv',index_col=0).reset_index(drop=True)
# ----> 3 df17 = pd.read_csv('2017/systematics.csv',index_col=0).reset_index(drop=True)
#       4 df18 = pd.read_csv('2018/systematics.csv',index_col=0).reset_index(drop=True)
#
# File /opt/conda/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.8/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File /opt/conda/lib/python3.8/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File /opt/conda/lib/python3.8/site-packages/pandas/io/parsers/readers.py:934, in TextFileReader.__init__(self, f, engine, **kwds)
#     931     self.options["has_index_names"] = kwds["has_index_names"]
#     933 self.handles: IOHandles | None = None
# --> 934 self._engine = self._make_engine(f, self.engine)
#
# File /opt/conda/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1218, in TextFileReader._make_engine(self, f, engine)
#    1214     mode = "rb"
#    1215 # error: No overload variant of "get_handle" matches argument types
#    1216 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1217 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1218 self.handles = get_handle(  # type: ignore[call-overload]
#    1219     f,
#    1220     mode,
#    1221     encoding=self.options.get("encoding", None),
#    1222     compression=self.options.get("compression", None),
#    1223     memory_map=self.options.get("memory_map", False),
#    1224     is_text=is_text,
#    1225     errors=self.options.get("encoding_errors", "strict"),
#    1226     storage_options=self.options.get("storage_options", None),
#    1227 )
#    1228 assert self.handles is not None
#    1229 f = self.handles.handle
#
# File /opt/conda/lib/python3.8/site-packages/pandas/io/common.py:786, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     781 elif isinstance(handle, str):
#     782     # Check whether the filename is to be opened in binary mode.
#     783     # Binary mode does not support 'encoding' and 'newline'.
#     784     if ioargs.encoding and "b" not in ioargs.mode:
#     785         # Encoding
# --> 786         handle = open(
#     787             handle,
#     788             ioargs.mode,
#     789             encoding=ioargs.encoding,
#     790             errors=errors,
#     791             newline="",
#     792         )
#     793     else:
#     794         # Binary mode
#     795         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '2017/systematics.csv'

# %%
s="DDB"
plot_systs_sig_bybin(s,df16apv,df16,df17,df18)
plot_systs_bkg_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/plotter.py:63: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:99: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:161: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:197: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="L1Prefiring"
plot_systs_sig_bybin(s,df16apv,df16,df17,df18)
plot_systs_bkg_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/plotter.py:63: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:99: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:161: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:197: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="JES"
plot_systs_sig_bybin(s,df16apv,df16,df17,df18)
plot_systs_bkg_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/plotter.py:63: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:99: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:161: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:197: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="JER"
plot_systs_sig_bybin(s,df16apv,df16,df17,df18)
plot_systs_bkg_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/plotter.py:63: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:99: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:161: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:197: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="UES"
plot_systs_sig_bybin(s,df16apv,df16,df17,df18)
plot_systs_bkg_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/plotter.py:63: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:99: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:161: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:197: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="jet_trigger"
plot_systs_sig_bybin(s,df16apv,df16,df17,df18)
plot_systs_bkg_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/plotter.py:63: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:99: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:161: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:197: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="pileup_weight"
plot_systs_sig_bybin(s,df16apv,df16,df17,df18)
plot_systs_bkg_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/plotter.py:63: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:99: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:161: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:197: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="btagSFlight"
plot_systs_sig_bybin(s,df16apv,df16,df17,df18)
plot_systs_bkg_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/plotter.py:63: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:99: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:161: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:197: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="btagSFbc"
plot_systs_sig_bybin(s,df16apv,df16,df17,df18)
plot_systs_bkg_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/plotter.py:63: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:99: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:161: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:197: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="PDF"
plot_systs_sig_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/plotter.py:63: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:99: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="scale"
plot_systs_sig_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/plotter.py:63: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:99: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="ISR"
plot_systs_sig_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/plotter.py:63: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:99: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="FSR"
plot_systs_sig_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/plotter.py:63: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:99: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="d1K_NLO"
plot_systs_vjets_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/plotter.py:269: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:306: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="d2K_NLO"
plot_systs_vjets_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/plotter.py:269: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:306: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="d3K_NLO"
plot_systs_vjets_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/plotter.py:269: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:306: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="d1kappa_EW"
plot_systs_vjets_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/plotter.py:269: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:306: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="d2kappa_EW"
plot_systs_vjets_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/plotter.py:269: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:306: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="d3kappa_EW"
plot_systs_vjets_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/plotter.py:269: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:306: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
np.unique(df16apv['bin'])
# Out:
# array(['ggf 1', 'ggf 2', 'ggf 3', 'ggf 4', 'ggf 5', 'ggf 6', 'vbf 1',
#        'vbf 2'], dtype=object)
